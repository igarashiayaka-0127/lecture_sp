# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### ヒートマップ作成コード

# %%
# Matplotlibの図（Figure）と軸（Axes）を作成
plt.figure(figsize=(8, 8))

# Seabornのヒートマップを描画
# cmap='coolwarm' または 'RdBu_r' などで赤-青系の色を指定
sns.heatmap(
    batting_averages,
    annot=True,              # セル内に数値を表示
    fmt=".3f",               # 表示形式を小数点以下3桁に指定
    linewidths=.5,           # セルの境界線の太さ
    linecolor='white',       # 境界線の色
    cmap='Reds',             # 赤系のカラーマップ（高い値が赤、低い値が白に近い）
    cbar=True,               # カラーバーを表示
    yticklabels=rows,        # Y軸（行）ラベル
    xticklabels=cols,        # X軸（列）ラベル
    vmin=0.150,              # カラーマップの最小値 (データの最小値より少し下を設定)
    vmax=0.400               # カラーマップの最大値 (データの最大値より少し上を設定)
)

# タイトルと軸ラベルの設定
plt.title('Course-Specific Batting Average Heatmap', fontsize=16)

# X軸とY軸のラベルの位置調整（野球のストライクゾーンのイメージに合わせるため）
plt.yticks(rotation=0)      # Y軸ラベルを横向きにする
plt.xticks(rotation=0)

# 描画された図を表示
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 14
#       2 plt.figure(figsize=(8, 8))
#       4 # Seabornのヒートマップを描画
#       5 # cmap='coolwarm' または 'RdBu_r' などで赤-青系の色を指定
#       6 sns.heatmap(
#       7     # batting_averages,
#       8     annot=True,              # セル内に数値を表示
#       9     fmt=".3f",               # 表示形式を小数点以下3桁に指定
#      10     linewidths=.5,           # セルの境界線の太さ
#      11     linecolor='white',       # 境界線の色
#      12     cmap='Reds',             # 赤系のカラーマップ（高い値が赤、低い値が白に近い）
#      13     cbar=True,               # カラーバーを表示
# ---> 14     yticklabels=rows,        # Y軸（行）ラベル
#      15     xticklabels=cols,        # X軸（列）ラベル
#      16     vmin=0.150,              # カラーマップの最小値 (データの最小値より少し下を設定)
#      17     vmax=0.400               # カラーマップの最大値 (データの最大値より少し上を設定)
#      18 )
#      20 # タイトルと軸ラベルの設定
# ...

# %% [markdown]
# ### データ処理

# %%
import pandas as pd
import numpy as np
